# %%
#!/usr/bin/env python3

# %%
# Importing the necessary modules 
import os 
import pandas as pd 
import numpy as np

# %%
# loading in the dataset  
conversation_dataset = "nlp_dataset/cornell movie-dialogs corpus/movie_conversations.txt"
movie_line_dataset = "nlp_dataset/cornell movie-dialogs corpus/movie_lines.txt" 

# load both datase  
conversation_df = pd.read_csv(conversation_dataset, sep=" ", header=None, error_bad_lines=False)  
movie_line_df = pd.read_csv(movie_line_dataset, sep=" ", header=None, error_bad_lines=False)
# Out:
# b'Skipping line 6: expected 10 fields, saw 11\nSkipping line 41: expected 10 fields, saw 11\nSkipping line 49: expected 10 fields, saw 14\nSkipping line 51: expected 10 fields, saw 11\nSkipping line 52: expected 10 fields, saw 12\nSkipping line 54: expected 10 fields, saw 11\nSkipping line 57: expected 10 fields, saw 11\nSkipping line 59: expected 10 fields, saw 11\nSkipping line 64: expected 10 fields, saw 13\nSkipping line 66: expected 10 fields, saw 12\nSkipping line 68: expected 10 fields, saw 15\nSkipping line 70: expected 10 fields, saw 12\nSkipping line 72: expected 10 fields, saw 11\nSkipping line 76: expected 10 fields, saw 14\nSkipping line 102: expected 10 fields, saw 12\nSkipping line 107: expected 10 fields, saw 11\nSkipping line 111: expected 10 fields, saw 12\nSkipping line 115: expected 10 fields, saw 12\nSkipping line 120: expected 10 fields, saw 11\nSkipping line 124: expected 10 fields, saw 12\nSkipping line 125: expected 10 fields, saw 12\nSkipping line 130: expec
# ...

# %%
# Splitting the conversation column into two values 
# conversation_df["conversations"].str.split("0\t", n=1, expand=True, )

# %%
conversation_df.head()

# %%
movie_line_df.head()
